# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os 
print(os.listdir("C:/Users/ADITYA AMAN/Desktop/MINI PROJECT"))
# Out:
# ['.ipynb_checkpoints', 'Google play store analysis.ipynb', 'googleplaystore.csv', 'googleplaystore_user_reviews.csv', 'Sentiment Analysis of GooglePlayStoreUserReviews.ipynb']

# %%
Data = pd.read_csv("C:/Users/ADITYA AMAN/Desktop/MINI PROJECT/googleplaystore_user_reviews.csv")#reads csv file to perform operations on it
Data.head()#It is used to return top n (5 by default) rows of a data frame or series.
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Now we'll be clearing our dataset by dropping all the rows with null values
Data = Data.dropna()# this method allows the user to analyze and drop Rows/Columns with Null values.
Data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
Data.Sentiment[Data.Sentiment_Polarity <=1  ] = 'Emotionally Positive'
Data.Sentiment[Data.Sentiment_Polarity <=0.5 ] = 'Rationally Positive'
Data.Sentiment[Data.Sentiment_Polarity ==0] = 'Neutral'
Data.Sentiment[Data.Sentiment_Polarity <0] = 'Rationally Negative'
Data.Sentiment[Data.Sentiment_Polarity <=-0.5] = 'Emotionally Negative'
Data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#               Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Emotionally Positive                1.00                0.533333
# 1   Rationally Positive                0.25                0.288462
# 3   Rationally Positive                0.40                0.875000
# 4  Emotionally Positive                1.00                0.300000
# 5  Emotionally Positive                1.00                0.300000

# %%
Data['Sentiment'].value_counts()
# Out:
# Rationally Positive     18016
# Rationally Negative      6952
# Emotionally Positive     5982
# Neutral                  5158
# Emotionally Negative     1319
# Name: Sentiment, dtype: int64

# %%
#Data.dtypes

# %%
#Data['Sentiment'] = Data['Sentiment'].astype('int')

# %%
import seaborn as sns #Seaborn is a Python data visualization library based on matplotlib.
import matplotlib.pyplot as plt #pyplot is matplotlib's plotting framework.
plt.figure(figsize=(18,18))
j = sns.scatterplot(Data['Sentiment_Polarity'],Data['Sentiment_Subjectivity'],hue=Data['Sentiment'], edgecolor='white',palette="plasma_r")
plt.xlabel('Sentiment Polarity', fontsize=20)
plt.ylabel('Sentiment Subjectivity', fontsize=20)
plt.title("Sentiment Analysis", fontsize=20)
plt.show()

# %%
import re#regular expression

import nltk#natural language toolkit
#nltk.download('stopwords')

from nltk.corpus import stopwords
# A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine has been programmed to ignore,
#both when indexing entries for searching and when retrieving them as the result of a search query.

from nltk.stem.porter import PorterStemmer #PorterStemmer Stemming produces morphological variants of a root/base word.

from nltk.tokenize import word_tokenize #A sentence or data can be split into words using the method word_tokenize():

# %%
Data.shape#Returns no of rows & columns in the dataset
# Out:
# (37427, 5)

# %%
Data["index"] = range(0,37427)
Data = Data.set_index("index")#indexing of data in the dataset
Data.head()
# Out:
#                          App  \
# index
# 0      10 Best Foods for You
# 1      10 Best Foods for You
# 2      10 Best Foods for You
# 3      10 Best Foods for You
# 4      10 Best Foods for You
#
#                                        Translated_Review  \
# index
# 0      I like eat delicious food. That's I'm cooking ...
# 1        This help eating healthy exercise regular basis
# 2             Works great especially going grocery store
# 3                                           Best idea us
# 4                                               Best way
#
#                   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# index
# 0      Emotionally Positive                1.00                0.533333
# 1       Rationally Positive                0.25                0.288462
# 2       Rationally Positive                0.40                0.875000
# 3      Emotionally Positive                1.00                0.300000
# 4      Emotionally Positive                1.00                0.300000

# %%
STOPWORDS = set(stopwords.words('english'))# words which are filtered out before or after processing of natural language data.
corpus=[]#corpus array stores the collection of text from translated review
         # Now we will be using the regular expression module to remove all unnecessary characters from the Translated Review
for i in range(0,37427):
    review = re.sub('[^a-zA-Z]', ' ',Data['Translated_Review'][i])#removes a non letter by replacing it with space
    review = re.sub('[/(){}\[\]\|@!,;]', ' ',Data['Translated_Review'][i])#removes brackets and punctuation marks
    review = re.sub('[^0-9a-z #+_♥️]', ' ',Data['Translated_Review'][i])#Remove bad words or symbols
    review = review.lower()#converts all uppercase letters to lowercase
    review = review.split()# returns a list of strings after breaking the given string by the specified separator.
    stemmer = PorterStemmer()#used to normalize the words
    review = [stemmer.stem(token) for token in review if token not in STOPWORDS] 
    review=' '.join(review)
    corpus.append(review)
corpus
# Out:
# ['like eat delici food hat cook food case 10 est ood help lot also est efor helf ife',
#  'help eat healthi exercis regular basi',
#  'ork great especi go groceri store',
#  'est idea us',
#  'est way',
#  'maze',
#  'ook forward app',
#  'help site help food get',
#  'good',
#  'seful inform amount spell error question valid inform share nce fix 5 star given',
#  'hank reat app dd arthriti eye immun kidney liver detox food pleas',
#  'reatest ever omplet awesom maintain health must ppl ove',
#  'ood health ood health first prioriti',
#  'ealth import world either life think',
#  'rs sunita bhati thank develop make kind app realli good healthi food bodi',
#  'eri seful diabet age 30 need control sugar thank',
#  'ne greatest app',
#  'good nice',
#  'ealthi ealli help',
#  'od health',
#  '5',
#  'n excel use',
#  'found lot wealth form health',
#  'ecaus found import',
#  'ealthi ate',
#  'eri good impli good',
#  'n test',
#  'ood',
#  'hank advic ownload dobe reader still get recip book',
#  'recip book nabl recip book',
#  'bsolut abul henomen',
#  'reat ove food',
#  'xcellent realli work',
#  'est',
#  'eri inform easi understand ad middl page interupt read pdate ad comment object ad liter posit ad mack dab new spartphon app idnt know lick eveyth saw ut ull eview',
#  'ot descript good',
#  'reat app ove',
#  'ood',
#  'ove eri help',
#  'ood healthi food',
#  'ast time need internet time n ask call inform',
#  'est thing lost ten lb two month help tip',
#  'en best food promot good health ood health essenti long healthi lifestyl make habit eat food promot good health fruit veggi everi day',
#  'ealthi ood ealli good inform eat healthi',
#  'mom dad import thing good share',
#  'big thank ds got bst gd health',
#  'ove est everyon need',
#  'ove lost 6 ound far 215 209',
#  'like',
#  'hank help app',
#  'good food realli good eat',
#  'hank hank u much',
#  'ove realli good',
#  'help',
#  'love',
#  'eri use',
#  'reat ove',
#  'eri inform',
#  'uv',
#  'great',
#  'onder',
#  'oesn work ero',
#  'eight loss ot bad',
#  '10 best food 4u xcellent chose food',
#  'need',
#  'altu plz wast ur time',
#  'est food hank recip book',
#  'ove ood',
#  'like uperb',
#  'ood good',
#  'ealthi',
#  'uick ead',
#  'reat idea',
#  'oo good',
#  'ool',
#  'ood',
#  'ood',
#  'est est',
#  'reat reat',
#  'ood list easi predibet scare r said potato rice bread e never told could eat suppli paperwork state thing could happen tell get work hank calm',
#  'reat wife wife enjoy much kinda person like follow health diet spend much time front find appropri diet food ow found magnific app hank humb',
#  'reat eri interest use applic like',
#  'rap oesn work',
#  '5 starr ownload',
#  'like help',
#  'nice super get',
#  'ice ice collect',
#  'ow',
#  'nterest interest info think worth storag space phone rather research comput print list eat idea make life easier provid entertain expect app',
#  'uv impl easi understand well thought follow step step problem see result also luv app give food choic ut look like foundat eep good work',
#  'ot good ts good u net connect u play app much good',
#  'wesom resourc begin new journey see great result',
#  'ore thought actual text oo poor old text',
#  'ove app give way good idea buy store eat daili basi',
#  'reat ts realli best uniqu provid detail inform food nutriti stay healthi hat develop give free',
#  'oth special ould find anyth use',
#  'ts ok love ok',
#  'like eat delici food hat cook food case 10 est ood help lot also est efor helf ife',
#  'help eat healthi exercis regular basi',
#  'ork great especi go groceri store',
#  'est idea us',
#  'est way',
#  'maze',
#  'ook forward app',
#  'help site help food get',
#  'good',
#  'seful inform amount spell error question valid inform share nce fix 5 star given',
#  'hank reat app dd arthriti eye immun kidney liver detox food pleas',
#  'reatest ever omplet awesom maintain health must ppl ove',
#  'ood health ood health first prioriti',
#  'ealth import world either life think',
#  'rs sunita bhati thank develop make kind app realli good healthi food bodi',
#  'eri seful diabet age 30 need control sugar thank',
#  'ne greatest app',
#  'good nice',
#  'ealthi ealli help',
#  'od health',
#  '5',
#  'n excel use',
#  'found lot wealth form health',
#  'ecaus found import',
#  'ealthi ate',
#  'eri good impli good',
#  'n test',
#  'ood',
#  'hank advic ownload dobe reader still get recip book',
#  'recip book nabl recip book',
#  'bsolut abul henomen',
#  'reat ove food',
#  'xcellent realli work',
#  'est',
#  'eri inform easi understand ad middl page interupt read pdate ad comment object ad liter posit ad mack dab new spartphon app idnt know lick eveyth saw ut ull eview',
#  'ot descript good',
#  'reat app ove',
#  'ood',
#  'ove eri help',
#  'ood healthi food',
#  'ast time need internet time n ask call inform',
#  'est thing lost ten lb two month help tip',
#  'en best food promot good health ood health essenti long healthi lifestyl make habit eat food promot good health fruit veggi everi day',
#  'ealthi ood ealli good inform eat healthi',
#  'mom dad import thing good share',
#  'big thank ds got bst gd health',
#  'ove est everyon need',
#  'ove lost 6 ound far 215 209',
#  'like',
#  'hank help app',
#  'good food realli good eat',
#  'hank hank u much',
#  'ove realli good',
#  'help',
#  'love',
#  'eri use',
#  'reat ove',
#  'eri inform',
#  'uv',
#  'great',
#  'onder',
#  'oesn work ero',
#  'eight loss ot bad',
#  '10 best food 4u xcellent chose food',
#  'need',
#  'altu plz wast ur time',
#  'est food hank recip book',
#  'ove ood',
#  'like uperb',
#  'ood good',
#  'ealthi',
#  'uick ead',
#  'reat idea',
#  'oo good',
#  'ool',
#  'ood',
#  'ood',
#  'est est',
#  'reat reat',
#  'ood list easi predibet scare r said potato rice bread e never told could eat suppli paperwork state thing could happen tell get work hank calm',
#  'reat wife wife enjoy much kinda person like follow health diet spend much time front find appropri diet food ow found magnific app hank humb',
#  'reat eri interest use applic like',
#  'rap oesn work',
#  '5 starr ownload',
#  'like help',
#  'nice super get',
#  'ice ice collect',
#  'ow',
#  'nterest interest info think worth storag space phone rather research comput print list eat idea make life easier provid entertain expect app',
#  'uv impl easi understand well thought follow step step problem see result also luv app give food choic ut look like foundat eep good work',
#  'ot good ts good u net connect u play app much good',
#  'wesom resourc begin new journey see great result',
#  'ore thought actual text oo poor old text',
#  'ove app give way good idea buy store eat daili basi',
#  'reat ts realli best uniqu provid detail inform food nutriti stay healthi hat develop give free',
#  'oth special ould find anyth use',
#  'ts ok love ok',
#  'reat',
#  'nice',
#  'lmost mobil phone',
#  'eri effect effici conveni find avail job eep good work power 104 ob earch',
#  'asi intuit',
#  'good search job internship',
#  'ot bad price littl bit expens',
#  'easi use',
#  'job search result e g secur',
#  'easi',
#  'ell also largest human bank aiwan pleas app ui',
#  'reat',
#  '',
#  'eri use',
#  'elp',
#  'eri good job hunt',
#  'asi use',
#  'nice',
#  'ood find job easili',
#  'ood meet good',
#  'wesomee',
#  'hy nglish version',
#  'oper interfac inform content richer 1111 also better use util without flash back',
#  'ice',
#  'develop method complet earli day comput web version mobil app function seem short function page exampl similar work function similar compani app version',
#  'better suit possibl somebodi understand pitfal modern technolog',
#  'seful handi termin mobil devic improv',
#  '104 job hunt amaz easi use thanx guy',
#  'onveni easi use mani larg corpor',
#  'asi use interfac',
#  'easi simpl easi use',
#  'easi found job',
#  'reat',
#  'seful use hines difficult peopl read hines f add nglish languag use',
#  'ell phone number fter complet resum 20 minut hit 4 mobil phone includ anshan ife nsuranc',
#  'eri help eri easi user friendli rilliant app',
#  'ood eri help',
#  'eri good conveni easi use beauti good',
#  'k',
#  'ice',
#  'orribl verif',
#  'asi even basic orean earch nglish usual bring result product ship oversea best search orean',
#  'ool',
#  'collect month refund e said would call month',
#  'op bar miss newest updat ard shop search',
#  'noth miss',
#  'efund take long 3 day still receiv money crazi',
#  'enjoy onlin shop via 11st app erfect',
#  'good enough',
#  'switch g arket wice 11st new face',
#  'forc full screen popup',
#  'sound like want clear hrome pay ndroid user pay hrome error fix app realli true makgeolli',
#  'k',
#  'tri updat everi time stall still difficult search tire see categori categori benefit get less less',
#  'ust tri far good',
#  'con name strang updat',
#  'com skplanet syruppay cardrecognizedlib',
#  'ice',
#  'best shop',
#  'forgot password get new',
#  'best',
#  'love',
#  'orc updat',
#  '',
#  'ove atur',
#  'anguag barrier understand orea want nglish',
#  'hip iew lexibl iew ake right hy come',
#  '0 point want give 10000000000000 point shortag click nternet address could find product pop 11th venu app automat turn automat abduct use internet app',
#  'ive star ts nice',
#  'orc termin sever f tri view detail inform forcibl termin',
#  'pen arket evolut section elo hip open market mobil servic still mani page area serv mobil servic interfac also urgent level page load f understand limit sourc control product inform provid seller chronic problem problem aris load coupon benefit manag page',
#  'nglish version possibl nglish version hank',
#  'f phone authent call agent abl find letter authent also e mail f thing call counselor',
#  'slow sinc last updat hard pay product give aliv',
#  'good good',
#  'f network error occur app save state tri tri point next time gone total tough',
#  'roblem languag dont understand languag use app advis keep option user choos languag may prefer',
#  'ice nice pp',
#  'nglish languag like',
#  'reat hassl free way order contact ot call remind prescript expir tomorrow',
#  'expens expect thought save money cut middl man waaaaay conveni doctor offic',
#  'uper fast navig brand fast easi checkout addit ad',
#  'asi step step process correct inform took 5 minut place order',
#  'lace order easi especi paper copi x updat review receiv order rebat',
#  'uper fast order reorder easi interfac ove conveni app',
#  'love make get contact easi ♥️',
#  'asi use ill def recommend',
#  'ove app uper easi use rdere contact less minut',
#  'easi use order process fast effici',
#  'simpl cave man',
#  'impl fast easi use eye appoint',
#  'eri user friendli',
#  'eri easi use ove free ship',
#  'eri easi use',
#  'ope',
#  'asi afford',
#  'asi',
#  'great',
#  'easi app ade order contact breez reat price',
#  'oe need sens give anyth less 5 star',
#  'ork well glad',
#  'hell lot easier thought would',
#  'made get new contact easi',
#  'love app easi super conveni',
#  'ope work well irst time user',
#  'ontact ship time effici',
#  'eri easi',
#  'asi access',
#  'irst time app alway use doctor offic stand behind tore contact ope solv problem 1800contact',
#  'onth later 9+ still notifi expir lens seless en notif work success push alert discount fundament reason keep run len expir notif work notif set fine',
#  'ood price except custom servic rder sent particular fault begin thoroughli check inform complet order hen email got respons rather quickli 2 hour correct made receiv free overnight ship ensur get lens promptli onder',
#  'quick easi order contact app love nd realli save time money make extrem happi ot love free market capit',
#  'rdere unday ot call verifi last name recent marri chedul ship onday appi custom',
#  'ook 5 second find rx get contact order conveni',
#  'hort simpl sweet uper easi took less 5 min order contact lu save',
#  'uper easi ot super cheap cheaper actual go optometrist good deal ship',
#  'eri use streamlin eye care need ecommend contact wearer 5 5 eri reliabl ship easi well',
#  'eri easi use hey rememb last order figur',
#  'well design easi conveni',
#  'reat hassl free way order contact ot call remind prescript expir tomorrow',
#  'expens expect thought save money cut middl man waaaaay conveni doctor offic',
#  'uper fast navig brand fast easi checkout addit ad',
#  'asi step step process correct inform took 5 minut place order',
#  'lace order easi especi paper copi x updat review receiv order rebat',
#  'uper fast order reorder easi interfac ove conveni app',
#  'love make get contact easi ♥️',
#  'asi use ill def recommend',
#  'ove app uper easi use rdere contact less minut',
#  'easi use order process fast effici',
#  'simpl cave man',
#  'impl fast easi use eye appoint',
#  'eri user friendli',
#  'eri easi use ove free ship',
#  'eri easi use',
#  'ope',
#  'asi afford',
#  'asi',
#  'great',
#  'easi app ade order contact breez reat price',
#  'oe need sens give anyth less 5 star',
#  'ork well glad',
#  'hell lot easier thought would',
#  'made get new contact easi',
#  'love app easi super conveni',
#  'ope work well irst time user',
#  'ontact ship time effici',
#  'eri easi',
#  'asi access',
#  'irst time app alway use doctor offic stand behind tore contact ope solv problem 1800contact',
#  'onth later 9+ still notifi expir lens seless en notif work success push alert discount fundament reason keep run len expir notif work notif set fine',
#  'ood price except custom servic rder sent particular fault begin thoroughli check inform complet order hen email got respons rather quickli 2 hour correct made receiv free overnight ship ensur get lens promptli onder',
#  'quick easi order contact app love nd realli save time money make extrem happi ot love free market capit',
#  'rdere unday ot call verifi last name recent marri chedul ship onday appi custom',
#  'ook 5 second find rx get contact order conveni',
#  'hort simpl sweet uper easi took less 5 min order contact lu save',
#  'uper easi ot super cheap cheaper actual go optometrist good deal ship',
#  'eri use streamlin eye care need ecommend contact wearer 5 5 eri reliabl ship easi well',
#  'eri easi use hey rememb last order figur',
#  'well design easi conveni',
#  'get 1 ad everi singl level restart frustrat potenti',
#  'game interest challeng owev often buffer get stuck',
#  'ow play 15 puzzl 1st round rememb puzzl solv childhood ove',
#  'ove game delet wait 3 month level play sever updat none updat ad new level',
#  'ay mani aggress ad',
#  'amaz addict',
#  'like game',
#  'play game',
#  'toooo gud game',
#  'oo mani unskipp ad ther great game',
#  'ind use game',
#  'oo much ad',
#  'great experi knowledg help game',
#  'ice game',
#  'realli good game',
#  'love game nice',
#  'granit',
#  'confus',
#  'ts realli fun',
#  'game beauti',
#  'uid',
#  '',
#  'yoko',
#  'great',
#  'eri nice',
#  'ood',
#  'ts cool',
#  'ool',
#  'antast',
#  'uperb',
#  'xcellent',
#  'ice',
#  'ove',
#  'un',
#  'njoy',
#  'ove',
#  'ood graphic ok mani ad ridicul skip bh wast time would recommend',
#  'erribl amount ad cover content make unpleas play void',
#  'ike ld ersion etter ackspac esid etter nd moji elow apit',
#  'like far',
#  'realli use realli like',
#  'send emoji without say chang input know chang input',
#  'ull h hen open app say sill never regist person data credit card number nce go activ de set messag pop say person data credit data enregistr ahha hat bullsh',
#  'ood',
#  'asi use best keyboard use',
#  'uzzi',
#  'love',
#  'erfect',
#  'wesom',
#  'good keyboard emoji user sensit constant nag chang theme disabl block top screen extrem irrit',
#  'last updat bug open keyboard set alway fc back old version',
#  'ork fine need updat',
#  'ou',
#  'hate',
#  'eh yeah',
#  'maze',
#  'maze app',
#  'ood emoji keyboard',
#  'lit',
#  'ts great',
#  'ove',
#  'ood',
#  'ove',
#  'ood',
#  'best emoji keyboard ever love',
#  'ood',
#  'fter updat emoji use normal',
#  'reat',
#  'est keyboard never freez like keyboard use never problem use think deserv 5 star',
#  'realli good go get ehh',
#  'erribl ot user friendli like origin app leas give custom option look forward navig cumbersom app amast',
#  'eepli disappoint free 21 day longer work ask high price medit expect prah involv scam respect',
#  'pdate 3 0 look good ould 5 without ad pictur purchas product take space phone product alreadi avail make pictur redund hank experi',
#  'guess pleas everyon love updat sure idea streamlin even read full titl medit tri use there problem love medit compar updat updat qualiti function like compar appl orang opinion sure look want chang feel complet mark',
#  'good ever get notif phone stop medit play annoy press play disturb medit prefer ed upgrad',
#  'abl listen 21 day past 2 frozen crash play like upgrad point lot',
#  'ove offer dislik intens keep play episod episod hour end sed stop select finish much better way',
#  'eem like updat occur let access free medit experi esterday today matter tri let rustrat',
#  '21 day medit attract first could see program free ut updat keep show order continu pay',
#  'tart anifest want rom 2nd ay edit holeheartedli hank eepak ji prah ring xcellent pp ighli ecommend',
#  'reat experi ser friendli navig',
#  'ool',
#  'would best crash time new version keep crash everi time open app miss 21 day experi one purchas cannot access get frustrat lu new version allow view daili medit ull eview',
#  '21 ay edit excel addit daili medit practic ruli enjoy listen prah eepak hort enough anytim would merit 5 star ongo glitch uninstal reinstal fix hen ull eview',
#  'glitchi phone ore often say mediat fail load avail delet reinstal sever time noth seem work rustrat',
#  'love medit session special love tri medit commit buy nd great custom servic coupl reason give 4 star 1 hey stop support older smartphon lower end ull eview',
#  'rozen ay 3 hing w move along great hit day 3 stuck everyday return back day wast time ew ear ame problem freez minut play nyth calm tran form experi',
#  'tress download start time got email say day expir within 5 day alreadi miss ay 1 need ay 2 day edit individu time frame nd want pay deep thinker ull eview',
#  'pdate pr 21 2018 love itl eliabl consist ld review 2015 ate everi night show unabl librari messag uninst n instal nightli ontact support team told work ad',
#  'reat medit wo thing wish would improv 1 allow daili remind item purchas librari set time daili remind 2 write journal blank space scroll would nice instruct scroll well bc much r ull eview',
#  'total awesom littl troubl time w want go back relisten rewind record freak close start',
#  'ay 1 2 fine ut day 3 froze quarter way thru medit hat disrupt rather onlin version ninstal',
#  'veral easi use ous medit program purchas place allow stream time ake particip 21 day program breez ave four star hang becom stuck sometim',
#  'egular free medit love hey like 1 2 spiritu teach 1 2 medit even bought quit reat valu',
#  'enjoy use complet medit anywher howev 21 day medit seri allow journal way onlin via desktop huge faux pa strongli import part experi',
#  'problem review mention work great love hear prah eepak voic calm great addit regular practic',
#  'ove music voic like access medit 21 day miss trip access',
#  'est pp hand love varieti sampl medit choos hat mediat intro read prepar what come duo dynam prah eepak forc reckon hank help becom best sel ull eview',
#  'content great hard use give sens action progress seem outdat poorli made easier need updat shame program good',
#  'extrem calm excel method center day bring anxieti stress level lead progress peac energet posit mindset highi recommend hard time reach true desir level ull eview',
#  'paid librari avail plu list free medit offer asi keep track navig oe alway allow listen download medit internet free experi regist get remind miss experi hank fix',
#  'ove access medit fter play day though jump back day start replay fix glitch',
#  'know begin ask whatev want call life forc receiv answer imagin incred posit creativ flow medit gener join togeth uli 23 unifi field within us ull eview',
#  'good updat ow cannot access journal entri say ournal avail medit everi day leas fix',
#  'love app quick easi use right size read abl medit anywher w laptop access email medit experi handi app love 21 ay experi get time hank much',
#  'love depend app journal would stay 5 day access free medit still made signific posit impact life',
#  'ice work consist ad frequent glitch bar access journal part content',
#  'hank chang permiss access hen done medit enjoy quiet auto play anoth right away make aw loud introduct next medit happen night use data catch leas consid chang rea ull eview',
#  'maze medit session nli wish option keep expir urrent shred weight prah absolut help stay track keep account',
#  'medit prah eepak use 21 day medit experi sever year ccasion topic practic reson enough bought look forward new 21 ay xperienc enthusiasm excit hey gui ull eview',
#  'erribl ot user friendli like origin app leas give custom option look forward navig cumbersom app amast',
#  'eepli disappoint free 21 day longer work ask high price medit expect prah involv scam respect',
#  'pdate 3 0 look good ould 5 without ad pictur purchas product take space phone product alreadi avail make pictur redund hank experi',
#  'guess pleas everyon love updat sure idea streamlin even read full titl medit tri use there problem love medit compar updat updat qualiti function like compar appl orang opinion sure look want chang feel complet mark',
#  'good ever get notif phone stop medit play annoy press play disturb medit prefer ed upgrad',
#  'abl listen 21 day past 2 frozen crash play like upgrad point lot',
#  'ove offer dislik intens keep play episod episod hour end sed stop select finish much better way',
#  'eem like updat occur let access free medit experi esterday today matter tri let rustrat',
#  '21 day medit attract first could see program free ut updat keep show order continu pay',
#  'tart anifest want rom 2nd ay edit holeheartedli hank eepak ji prah ring xcellent pp ighli ecommend',
#  'reat experi ser friendli navig',
#  'ool',
#  'would best crash time new version keep crash everi time open app miss 21 day experi one purchas cannot access get frustrat lu new version allow view daili medit ull eview',
#  '21 ay edit excel addit daili medit practic ruli enjoy listen prah eepak hort enough anytim would merit 5 star ongo glitch uninstal reinstal fix hen ull eview',
#  'glitchi phone ore often say mediat fail load avail delet reinstal sever time noth seem work rustrat',
#  'love medit session special love tri medit commit buy nd great custom servic coupl reason give 4 star 1 hey stop support older smartphon lower end ull eview',
#  'rozen ay 3 hing w move along great hit day 3 stuck everyday return back day wast time ew ear ame problem freez minut play nyth calm tran form experi',
#  'tress download start time got email say day expir within 5 day alreadi miss ay 1 need ay 2 day edit individu time frame nd want pay deep thinker ull eview',
#  'pdate pr 21 2018 love itl eliabl consist ld review 2015 ate everi night show unabl librari messag uninst n instal nightli ontact support team told work ad',
#  'reat medit wo thing wish would improv 1 allow daili remind item purchas librari set time daili remind 2 write journal blank space scroll would nice instruct scroll well bc much r ull eview',
#  'total awesom littl troubl time w want go back relisten rewind record freak close start',
#  'ay 1 2 fine ut day 3 froze quarter way thru medit hat disrupt rather onlin version ninstal',
#  'veral easi use ous medit program purchas place allow stream time ake particip 21 day program breez ave four star hang becom stuck sometim',
#  'egular free medit love hey like 1 2 spiritu teach 1 2 medit even bought quit reat valu',
#  'enjoy use complet medit anywher howev 21 day medit seri allow journal way onlin via desktop huge faux pa strongli import part experi',
#  'problem review mention work great love hear prah eepak voic calm great addit regular practic',
#  'ove music voic like access medit 21 day miss trip access',
#  'est pp hand love varieti sampl medit choos hat mediat intro read prepar what come duo dynam prah eepak forc reckon hank help becom best sel ull eview',
#  'content great hard use give sens action progress seem outdat poorli made easier need updat shame program good',
#  'extrem calm excel method center day bring anxieti stress level lead progress peac energet posit mindset highi recommend hard time reach true desir level ull eview',
#  'paid librari avail plu list free medit offer asi keep track navig oe alway allow listen download medit internet free experi regist get remind miss experi hank fix',
#  'ove access medit fter play day though jump back day start replay fix glitch',
#  'know begin ask whatev want call life forc receiv answer imagin incred posit creativ flow medit gener join togeth uli 23 unifi field within us ull eview',
#  'good updat ow cannot access journal entri say ournal avail medit everi day leas fix',
#  'impl easi use unnecessarili wast time good invest time person growth',
#  'love app quick easi use right size read abl medit anywher w laptop access email medit experi handi app love 21 ay experi get time hank much',
#  'love depend app journal would stay 5 day access free medit still made signific posit impact life',
#  'ice work consist ad frequent glitch bar access journal part content',
#  'hank chang permiss access hen done medit enjoy quiet auto play anoth right away make aw loud introduct next medit happen night use data catch leas consid chang rea ull eview',
#  'maze medit session nli wish option keep expir urrent shred weight prah absolut help stay track keep account',
#  'good date app love much lot hines nglish speak member ost activ chat request soon regist advertis chat other member freeli use differ date app function simpl direct one ser exchang contact easili hose guy met nice gentl seriou eel good ope everi enjoy use app',
#  'hank friend introduc date chang impress date app first time real date real life date app happi satisfi qualiti app especi excel custom servic function user orient local user activ wait long user repli match inal honestli give big like app ope enjoy app',
#  'seem nice need even send messag anoth parti issu user wish pay membership time understand send msg first parti msg abl repli without problem',
#  'ont wast money becom on scam rubbish',
#  'u ng app ust wast time ou send receiv heart sign send receiv messag sking money messag etter find anoth platform',
#  'like date much iffer date app member truli want make friend person inform user good detail help easili understand member unction interfac date simpl user friendli advertis easi get start find someon chat directli ser activ seriou met member similar interest valu e din offlin sometim join activ other hope everyon make friend find half',
#  'happi interest ello friend glad meet u et enjoy',
#  'ell actual good thing allow match 30 day plu filter countri u want social happen randomli chosen',
#  'ice mani gal ser friendli good date app much better other',
#  'ice attract function ember friendli est choic meet new friend',
#  'ice attract function ser nice feel good',
#  'ice mani function best meet friend',
#  'ou chat girl without pay premium ast time',
#  'hat behind paywal ou unabl initi convers anyon without pay subscript fee',
#  'ts hard send messag like also worst site need vip member send messag',
#  'ice mani gal ser friendli great easi use _',
#  'ice also user much friendli ove',
#  'f dont want spend money date dont need make payment becom chat other',
#  'hy cant repli messag',
#  'good way start someth differ',
#  'ust nice sote focu want',
#  'ice alot user',
#  'ice mani peopl insid',
#  'e even send messag anyon unless ember pure busi',
#  'receiv email nd repli messag',
#  'app worthi prais still need work hard',
#  'cool hard use hard',
#  'ice mani member like',
#  'ot good even simplest messag function need',
#  'oe necassari vip member sent messag other',
#  'lot fake account',
#  'ealli worth tri date platform good qualiti',
#  'ice app eopl friendli ike',
#  'ice mani member ser activ great easi use',
#  'easi access',
#  'osan wong',
#  'ice mani gal user friendli ell design easi _',
#  'perfect',
#  'hank lot excel map 2gi love like much work well even without data connect help peopl ahead keep us',
#  'applic much help connect n addit rout total transport citi huge plu',
#  'eri good app ou get lost anywher',
#  'ot show easili fastest rout nite rab mirat take longitud latitud map coordin input everi locat nite rab mirat need updat map latest 3 poi restaur hotel tm',
#  'use find offic place ove offlin facil',
#  'ove caus alway give date inform realli use',
#  'lot intrus advertis suggest invit becom agent photograph',
#  'ask add opportun watch buse current onlin display andex transport',
#  'ncreas launch speed weak devic',
#  'eed improv lot locat search suggest',
#  'like map show abu dhabi want add abu habi also possibl',
#  'revious applic eat less batteri consumpt estim phone high intens',
#  'move anoth citi without know area verywher applic help',
#  'ake life easi thank lot 2',
#  'use ts help alway find locat',
#  'oth',
#  'wish map countri around world',
#  'lreadi coupl week buggi hat happen veryth happen slowli delay r even hang',
#  'good applic need work updat exampl object built',
#  'realli good offlin navig visit visa ubai help lot navig search job feedback would like develop know development activ rout chang also stop chang pleas updat',
#  'think great u add notif app ex one two busstop till destin point peopl could leav open without check watch way like littl paranoid scare miss stop',
#  'applic healthi know much applic start hang constantli fli eri often white screen appear applic hang',
#  'veryth fine reason stop updat map exampl xhibit conom chievement long time repair postpon transfer hope uli updat fix noth happen',
#  'esterday took wrong locat go meet eet got cancel delay reach right place n l uoz ubai',
#  'hank app often differ citi go leas add ashkent citi capit zbakist',
#  'good peopl send work plz check',
#  'wesommmmmmmmmm app st dwnld nd nji e nt get trap anywhr akka',
#  'alway use applic think conveni interfac offlin map surpris find list citi insk download competitor applic',
#  '',
#  'onstantli fli imposs use amsung galaxi note 4',
#  'maze pleas add multipl destin',
#  'ool prog rescu',
#  'pedestrian especi foreign citi know applic better ut sit behind wheel impress spoil still conveni find place go epeatedli navig offer roll turn around would roadway oncom traffic ot mention fact navig sometim offer dirt road instead normal one spent whole night track winter',
#  'isgust first everyth fine know languag turn say applic pereklinilo offer twice exact opposit rout eri much advis download dare readi instead right place go eboni sure go right',
#  'est map ubai harjah jman pleas add bu habi l khaima ujairah mm l wain',
#  'use without internet',
#  'umber ap world',
#  'lway help',
#  'maze ut also need locat abu dhabi plzzzzz',
#  'icon thank',
#  'hat wait oin platform thank later',
#  'reat',
#  'nice',
#  'inda good know find ms right',
#  'excit experi meet someon dont idea',
#  'est date ever',
#  'eri good',
#  'eri nice',
#  'ice',
#  'ood',
#  'ool',
#  'ood app could free featur like translat search engin set',
#  'et tri first',
#  'chat',
#  'xcellent',
#  'k',
#  'ust new',
#  'eri good',
#  'realli like could help find futur hines husband realli want name black woman realli cool get find hines hous find hines guy attract need better look apanes guy cuz apanes guy got flat face',
#  'reat love',
#  'ood fun',
#  'impl',
#  'wesom',
#  'ood',
#  'realli great app found girlfriend use 2 ed ean life much better pretti cute fit requir ould imagin life us 2 ed ean ighli recommend',
#  'hate take requir send messag',
#  'ladi find partner hen men tri make friend ladi 5 ladi repli chat',
#  'maze app easi intuit found half 2 ed ean highli recommend',
#  'good full real peopl',
#  'hard',
#  'ice g',
#  'ice',
#  'ice app efinit need pay benefit way filter citi see nearbi like websit',
#  'ad said free chat',
#  'ope wish come true',
#  'weet',
#  'ubbish',
#  'hief',
#  'good way know mani new friend friend also pay explor new world',
#  'realli good problem hen make groupchat tell whole groupchat email use second line creat chat send messag groupchat actul messag say email would like fix pleas ther amaz',
#  'veryday someon keep call kinda bug everi night send guy email everi detail freakin mysteri call hope hear good news',
#  'hank fix notif problem new recent updat give 5 star caus miss call text anymor',
#  'hen get phone call make make person line',
#  'whenev number verif say cannot plzz tell',
#  'ring phone',
#  'aap awesom',
#  'ight',
#  'realli like featur realli send receiv call wifi 4 owev queri develop 1 hy abl number whatsapp facebook registr 2 hy abl call base landlin number est good far hank ton',
#  'love ad start pop use et rid ad domin entir screen hate least put ad corner make small realli hinder well app',
#  'use remium still poor qualiti call oic break badli sometim peopl even understand tell 4 connect poorli design',
#  'even delet first download co even let regist leas need work app',
#  'call keep drop complet suck tri take care import call handl busi may abl reach person need talk',
#  'creat account eep say n error occur rie differ email differ password oth',
#  'ant creat account rie 4 differ email say error occur ast time ninstal',
#  'keep drop open n lose signal take long load riend receiv photo send',
#  'eep crash eep end call leas fix n note 8',
#  'fix problem error occur happi give five star',
#  'instal sign abl make call text receiv send number tri also canada number respons',
#  'realli like app ut want know avail hone',
#  'cannot creat account alway pop connect error occur',
#  'pay 10 credit make intern call never reciev',
#  'act weird sometim frustrat need good line connect peopl',
#  'show error signup',
#  'allow sign ix problem',
#  'nabl sing lway show error',
#  'error occur bata raha hai',
#  'creat account say error occur',
#  'weet origin number call text friend famili',
#  'hen creat account alway show error occur',
#  'ts good creat number show error occur lz fix',
#  'rror occur sign',
#  'emov add sign sure',
#  'reat app ou made great enjoy love 2nd ine',
#  'rror heck',
#  'nabl creat account',
#  'lway error',
#  'great app easi work well',
#  'eri nice easi',
#  'ood busi line ow make wifi compat',
#  'great u ad exercis mean chest back shoulder',
#  'ome time exercis match design bodi part aim work ut still great',
#  'elp get ideal bodi want',
#  'lway challeng definetli worth feel energet loos day ade better power put littl eas tell almost give good advic',
#  'eri challeng est workout far ove',
#  'disappoint confus abl understand level beginn intermedi advanc exercis audio also work well workout full bodi workout content avail 100 full bodi workout accur way someth satisfact',
#  'ealli good show workout move',
#  'ave fun rother make lot fun hank',
#  'reat person train',
#  'eri help',
#  'ove',
#  'tri multipl workout seem alway come back one workout categor give much break need workout also rest day realli like start easi progress day go also connect oogl',
#  'start find motiv go gym found 30 day good way keep gave lot motiv ometh usual struggl calori control diet give chocol 2 month lost stone start medium silver complet hard silver side plank 10 second start hold 60 second ot sure go certainli improv thank app',
#  'realli enjoy app love workout option workout get challeng progress feel get stronger want pay app saw review year state free version option would like buy wait ensur bug fix first',
#  'pleas tell realli confus weight loss hould follow easi medium hard level daili complet monthli',
#  'good gym instructor cover home exercis easili effect left exercis day remind come back provid exercis may look effect 3 week love app thank design thank much',
#  'easi use erfect peopl look workout home ou make easi hard want categori make longer workout like',
#  'ove simpl effect eek 2 easi program lost 1 5 inch waist recommend friend famili even got husband workout',
#  'get anywher weight loss goal husband introduc app achiev easili everi amaz transform',
#  'reat app help keep track workout give tip exercis workout short get tire lot ad',
#  'ust start work slow back injuri great work pace',
#  'reat app keep motiv ove 30 day challeng end sight even 30 day',
#  'uick easi way work without go gym',
#  'hate forc exercis everyday',
#  'help lot lose weight use sinc earli juli current lose 2 kg ++ hee pray keep lose weight',
#  'realli love like actual show',
#  'mani ad part workout realli effect 15th day notic chang seen',
#  'help get back great shape often get complement tone look',
#  'ike workout ust wish varieti workout',
#  'reat app easi great combin exercis keep thing interest',
#  'diet chart also help us ccord everyon need diet also necessari',
#  'amaz highlight within may post download see highlight otherwis like listen hope guy would suggest idea may allow user post highlight match ell hope would look',
#  'log google+ mani ad irit pleas remov ad fix log problem',
#  'leas updat player list liga 1 indonesia',
#  'reat issu sort',
#  'amaz need new design',
#  'leas add play play score especi',
#  'eri wonder applic',
#  'best work use',
#  'live olorado pring olorado eed say',
#  'xcellent',
#  'etter brainless runner actual make think',
#  'cool game like much help develop concentr',
#  'xcellent realli tough higher level',
#  'great game keep u busi hour bviousli u know play',
#  'impl game pass time away grandson like',
#  'reat way waist time',
#  'reat',
#  'onnect four good',
#  'ore put chip hole let win',
#  'uper fun game ealli good brain game',
#  'bore game sooooo bore _',
#  'ould made better improv manoeuvr',
#  'ddictiv play almost everi day year version',
#  '4 row ho knew 4 row could fun',
#  'eep busi',
#  'ove ♥thi game rock ♥',
#  'ice simpl game',
#  'love',
#  'play level 10 three time hen program let go second level 10 fifteen time could make suggest improv evalu function like use concept zugzwang accur',
#  'ice wallpap 4k even 2k present hey hardli full perhap scale 4k make look graini blurri ould recommend phone screen resolut higher full ice collect great qualiti unfortun',
#  'refresh function scrambl excist wallpap ho fool ot wallpap bad qualiti wast time',
#  'wesom app allpap vibrant exclus mostli ut excess ad make miser wallpap leas least reduc',
#  'ould better add anim wallpap veral good daili updat wallpap',
#  'true 4k wallpap great varieti new wallpap must ad frequent',
#  'good better 4k pictur',
#  'uperb love wallpap give confid whenev look',
#  'realli cool amaz graphic realli enjoy scroll threw look',
#  'gd bad',
#  'good search hous',
#  'app basic landlord seller orient design user friendli easi tenant search fill bunch advertis fake landlord agent advertis may main sourc incom 591 design tenant buyer easi search hous compani care tenant live want advertis revenu ill consid conveni use search strongli recommend use app search hous',
#  'given exampl hat els unclear make money hat debug user help ould like send case earch screen littl rotten find result team screen screen exampl earch aichung iti map mode independ suit screen open fire balconi find bunch non conform condit',
#  'ap mode see number object approxim locat click view page object troubl thank oto play ndroid 6 0 1 3 5 4',
#  'also telephon inform also set becom troublesom necessari us download use app',
#  'otten ush broadcast push otten',
#  'eed phone permiss way',
#  'english uch shame',
#  'erson collect synchron web version account ad collect comput fter app log none synchron',
#  'ssential essenti foreign live aiwan sure nglish ersion creat simpl translat app speak mandarin would almost imposs read fine line leas get work',
#  'post top let',
#  'hat guy encent folder call tencent push instal root directori intern storag updat latest version log directori show receiv push content com tencent andriod tpush action show aiwan compani guy encent trust hines compani choic uninstal app',
#  'anguag nglish option',
#  'leas fix updat hous inform seen rental hous',
#  'nglish version pleas',
#  '1 ook filter criteria 2 etter store filter criteria futur',
#  'oo mani ad',
#  'lot time lot time manag easi take care',
#  'till room improv',
#  'turn notif still keep post',
#  'locat correct',
#  'good',
#  'ot friendli nglish speaker nli nglish interfac appli content ot suitabl nglish speaker',
#  'ealli help app',
#  'far like option talk get help connect great owev qite bug glitch sure upgrad would offer wouldnt consid bug work great idea could help mani peopl pleas fix bug',
#  'realli awesom pp hen problem alway talk peopl make feel better hank',
#  'eah 7 cup fine glitchi sometim less featur avail',
#  'uick honest respons',
#  'eri help',
#  'huge issu call listen hese peopl idea go spread misinform mental health lack empathi never repli hen polit told listen unhelp told therapi useless joke block serious hope peopl never go advic support careless knowledg issu discuss even though found categori leas train listen properli',
#  'oy buggi low slow fact sure still run listen nice gener hat actual connect one show mani listen avail activ nd pushi constantli tri get pay therapist app',
#  'absolut amaz heal help anxieti depress ts hard peopl say stop wimp there peopl real problem thoos problem feel nice vent everyth',
#  'simpl way view eat get better idea habit reason though crash girlfriend everi singl time open e open close error open time infuri asn updat year dont know still develop abandonwar hey still happi charg 4 month though',
#  'good app work ften repeat error messag close abruptli',
#  'ould open week onstant crash respons develop fb page owev work great',
#  'pointless download instal find 7 day free trial start pay monthli',
#  'enjoy app wish crash everi time tri go back',
#  'avent abl open ver week',
#  'ot great busi model list free realli use sinc wo rand love disappoint fee mislabel free rather free ad option pay ad free version',
#  'use free call wo rand ou could see other meal hey chang mani time suck',
#  'ay complet free free 7 day 2 99 per month get free 7 day complet impli without restrict ork fine take pictur food',
#  'like pace varieti hear timer music play mute music updat ice app',
#  'superb app offic goin staff businessman less time 15 mint exercis keep bodi fit act like instructor u enjoy good',
#  'great remind workout tailor abil wish preview workout video form start workout',
#  'far good got everyth need simpl well illustr exercis lite voic time stay might tempt get ad free version soon',
#  'love app realli keep motiv better physic super easi home',
#  'hould put tim hard plan 2 fr complet within 7 minut idea wen rest within exercis',
#  'ew blip audio imag great quick way stay littl activ',
#  'love much interest easi without need go gym',
#  'ust first time feel exhaust good job',
#  'reat app 7 minut defin make sweat',
#  'good want exercis',
#  'bland bore even paid level ot recommend till add featur ish field new habit section add detail also abil colour code habit organ better perhap categori section sort habit ie habit improv school life work life etc n instal till thing ad',
#  'inimalist ffecient exactli advertis design sleek instruct clear switch anoth complic object tracker work time week date night week option skip day hat ewir tad better manag ut tire',
#  'onder done amaz thing perfectionist attitud use make long imposs complet list finish veryday felt like failur ow list coupl thing finish day final rom time time add coupl new thing abl finish list feel free fail everyday hank much creat app',
#  'work wonder problem find think current day bit lag behind sometim get earli still highlight previou day ut big issu asid perfect ighli recommend anyon want track habit',
#  'mall bug yet start realli use concept seem good set habit start date week yet get daili notif like hile appreci motiv spirit save habit start date',
#  'een use whole year almost everyday goddamn without write review often deserv prais given maze app intuit easi use 5 5',
#  'reat concept ut also think thing front everyday feel like like look posit way o pushup best target smoke anyth advic ayb develop take innov way think solut',
#  'like tri abit ull abul e etc interfac workflow much focus overwhelm ut thing almost habit tracker miss complement hope 7 eek among first sinc invest bought premium version',
#  'think great app ut uch cheaper calendar phone notebook think worth money ut great concept tho special peopl realli struggl bad certain addict uch love app ut uninstal hank tho',
#  'bought plu version love reat altern notecard activ widget uggest hen reach end habit habit break time set creation habit say ou complet habit forc reset wish could choos continu indefinit without time goal set lso set habit break time mark lot day incomplet end time still see ou complet habit realli true wish punish incomplet day sever mayb time goal reset mayb someth less dramat',
#  'ts habit tracker habit motiv allow name make person habit ike want upgrad clash clan build everi morn let name habit make 5 star',
#  'omplet goal give red usual neg symbol feel good see also seem way set goal specif day everi day mean forc break streak take rest day make feel bad',
#  'ought cross hen achiev task assign day miss chang ot cross look like lot wrong therefor lot miss circl end look posit hy choos icon r green circl achiev red miss',
#  'ts great app simpl clear remind realli help realli help chang habit ne thing like would abl altern day yoga day run next',
#  'better pool game oogl lay slightli buggi hen oppon connect stabl suddenli say run time even though made shot also seem support push timer need b obviou run',
#  'ate get cue piec max cue ealli wish guy would chang eep get 8 n 12 hr box airo elhi n end get 2 3 piec use omplet wast time hang n review goe back 5 star',
#  'ame alright bit sketchi either oppon bad connect pool cue power bar need look annoy tri get right amount power suddenli start move angl finger move bar',
#  'realli like game tri ti purchas halloween pack twice amount got deduct bank account transact pool show declin ould u pleas let knw whether get pack money back',
#  'orst server ran rom first time tri game acout messag connect slow tri best network ran ecent even connect game time leas consid better server caus mani ranian love game',
#  'previou profil howev updat lost 1 5 million coin rank ow sad frustrat start f 8 ball fix give five star',
#  'ove game issu request gift club advis restart phone close open even check updat ny help would great work fine today',
#  'want enjoy game hack death mani peopl becom bore ou pot ball back u start turn uper fast fiber bb connect badli maintain app',
#  'ealli love wish like real pool f sink stripe break stripe nd suck get beat someon shoot random win shoot full power hope sink ball pocket call ther love',
#  'ealli hat think game awesom play tabl pool time game real life pool eopl complain control develop fault individu fault f know manipul easi 8 pool peac men',
#  'orri greedi love game sinc start ow club creat go 1 1 differ club game would outstand happen rate star get attent orri',
#  'ealli good addict game e girlfriend constantli play downfal sometim watch video free money dont emd get happen numer time great game',
#  'ame cut sometim u loos turn sometim caus match loss also spend money recharg stick what play real bca pool effort effect',
#  'actual addict game seem wierd critic time game go win match game shut time get reboot lost nli time ever critic moment never play romis game total rig hat perfectli clear spin wheel alway land low #s hat chanc otherwis ig',
#  '999999 time never got 500 coin game tell buy better spin ame shame ot air erious ut mani spin get noth good unlucki',
#  '700 hundr coin new 300 even win game player back play wait player back still get extra 50 coin win 100 go abl play day till build coin',
#  'ndian cheat ou see option choos oppon base wish play 100 million cheat ndian permantli onlin',
#  'instal trip thought would wifi decid practic offlin mode adli game money play offlin want wast hen got back tri actual game work fine middl game close id mention take forev load time got back alreadi lost happen lost money realli feel like play anymor',
#  'made chicken eat mice oo mani conveni bug big game ree spin joke hy wait oppon respons lot flaw ot sure rig seem like',
#  'give 5 star everytim offer free cash goe get level requir till issu either ever friend problem quit offer',
#  'enjoy game much last 4 game ive play either taken money automat said oppon im game take shot say ran time automat win ix problem ill rate 5 star mani lag game like monaco lag dozen like somehow manag buy cue twice end bare money',
#  'use love gsme ow much made purchas nd didnt receiv purchas lso coin csme gone without approv need fix spent lot money thru googl play angri f isnt fix soon purchas coin replac delet gsme take action iniclip hsppi',
# ...
#  'ame alright bit sketchi either oppon bad connect pool cue power bar need look annoy tri get right amount power suddenli start move angl finger move bar',
#  'realli like game tri ti purchas halloween pack twice amount got deduct bank account transact pool show declin ould u pleas let knw whether get pack money back',
#  'wesom like look see ickatnyt play olt lad ad club game need ne thing though player get hope win big daili spin rig get low prize',
#  'realli enjoy play reat graphic ever problem connect issu cheat owev spin wheel never land anyth 250 ish lower level option guidelin call pocket hate lose pponent slop shot',
#  'free spin joke 4 slot 250 lower alway land 4 16 dd say control u spend money eem like play ton bot here merican',
#  'ealli hat think game awesom play tabl pool time game real life pool eopl complain control develop fault individu fault f know manipul easi 8 pool peac men',
#  'actual addict game seem wierd critic time game go win match game shut time get reboot lost nli time ever critic moment never play romis game total rig hat perfectli clear spin wheel alway land low #s hat chanc otherwis ig',
#  'orst server ran rom first time tri game acout messag connect slow tri best network ran ecent even connect game time leas consid better server caus mani ranian love game',
#  'unni game never see cue batteri insid ou earn upgrad pay coin stupid ut recharg cue u use stupid thing back star keep ask rate game stil noth improv call pocket game pot ball wrong pocket ball hand oppon lose turn',
#  'previou profil howev updat lost 1 5 million coin rank ow sad frustrat start f 8 ball fix give five star',
#  'love game ust thing want review regard account deactiv reset delet ou made complic f avail game set b awesom last thing regard name chang venthought chang name facebook miniclip account still noth chang game us option f could fix rate 5 star sure whether realli look problem begin nyway thankyou team',
#  'ake money differ rate 11700 coin went 2500 game lost round come money gone lso offer get coin dont get ix glitch idiot want coin back',
#  'reat game se play mini clip year ago ook star cant block peopl play poorli e purpos scratch break scratch caus dont shot ont play like bitch',
#  'play pool game stand alon ou buy anyth progress faster choos thing would improv game bigger bonus ou know time get get new addit work fine addit game efinit pool game get addict',
#  'orri greedi love game sinc start ow club creat go 1 1 differ club game would outstand happen rate star get attent orri',
#  'game get better slowli still never got back 50 million coin lost due hacker affect everyon back nd design still made option turn daili deal post fb play someon new hose popup seem keep happen frequent get annoy lot peopl would agre option',
#  'ove game issu request gift club advis restart phone close open even check updat ny help would great work fine today',
#  'want enjoy game hack death mani peopl becom bore ou pot ball back u start turn uper fast fiber bb connect badli maintain app',
#  'ealli good addict game e girlfriend constantli play downfal sometim watch video free money dont emd get happen numer time great game',
#  'good game spin win wheel definit rig highest ever gotten 500 coin lso use wait 15 second open ro box wait 3 hour disappoint situat',
#  'ame cut sometim u loos turn sometim caus match loss also spend money recharg stick what play real bca pool effort effect',
#  '999999 time never got 500 coin game tell buy better spin ame shame ot air erious ut mani spin get noth good unlucki',
#  '700 hundr coin new 300 even win game player back play wait player back still get extra 50 coin win 100 go abl play day till build coin',
#  'ndian cheat ou see option choos oppon base wish play 100 million cheat ndian permantli onlin',
#  'instal trip thought would wifi decid practic offlin mode adli game money play offlin want wast hen got back tri actual game work fine middl game close id mention take forev load time got back alreadi lost happen lost money realli feel like play anymor',
#  'made chicken eat mice oo mani conveni bug big game ree spin joke hy wait oppon respons lot flaw ot sure rig seem like',
#  'give 5 star everytim offer free cash goe get level requir till issu either ever friend problem quit offer',
#  'enjoy game much last 4 game ive play either taken money automat said oppon im game take shot say ran time automat win ix problem ill rate 5 star mani lag game like monaco lag dozen like somehow manag buy cue twice end bare money',
#  'know deal hone shut turn back play game eep happen hile play big money game ther like game',
#  'use love gsme ow much made purchas nd didnt receiv purchas lso coin csme gone without approv need fix spent lot money thru googl play angri f isnt fix soon purchas coin replac delet gsme take action iniclip hsppi',
#  'ame reez play oo mani problem mention nd ad like game plan play elet asap leas want sain',
#  'ealli love wish like real pool f sink stripe break stripe nd suck get beat someon shoot random win shoot full power hope sink ball pocket call ther love',
#  'ame awesom sever bug fix nd annoy thing might spin wheel 1000 time prize got 500 coin hy prize show minigam love option chang ball 1 cash current first ball ope see chang soon game',
#  'type glitch clock aim cue stroke cue layer hack game put updat mode lose ame allow collect win advanc ou must wait hour f choos leav updat mode lose win previous game ven though screen lock lame',
#  'far great game havent swarm ad usual everi game thoroughli enjoy gameplay long time fan pool reat play friend good time killer',
#  'spin model correctli ackspin noth nd number time watch ball pot slower ball hit oppon go n top white ball roll way much even low power n top pretti sure rule game model incorrect someth tk watch ther major physic rule base issu actual fun game play',
#  'wo screen show match frustrat unnecessari special 5 sec delay right match player win well understood coin get transfer',
#  'all 8 ool 75 rule make 8 ball pool absent instanc make 8 break pull put right back center tabl scratch 8 lose game unless made 8 make ball break tabl still open get choos want make break follow make anoth ball still open game suck dick go tri compar 8 ool sinc premis game miss complet 8 ool built fact make 8 ball break scratch win fun game 8 ool even allow name',
#  'keep get request gift even though person say sent never sent know today got request friend pass away coupl month ago bsolut disgust 1 star',
#  'eri good game good wish aim graphic longer aim line would nice tutori make shot hit cue nglish cue',
#  'ove game spend alot time play good understand tri make money sure blunti coiner ut game pretti set win id i0 90 win would think have smoke coiner would spend wise great game fond cheat prevent set win',
#  'hate fact win get 8ball break hat real pool anywher world hate play game get stuck play someon doubl level match level ther cool',
#  'ice game away time alreadi addict time countri low etwork make inevit lose interest game alreadi advantag reat ame abul raphic',
#  'ame bad compani tri hardest get hard earn dollar return ry creat new account everi day 10 day guarante everi first wheel spin scratcher 250 40 time row result rook ss compani feel bad peopl give compani money mini game obvious rig hey chang game still rig hey rot',
#  'hy wait oppon readi shoot lso noth bunch amateur slam ball around tabl get lucki block shot',
#  'matter much updat still cant get physic real pool ing pool alot peopl anyon want play real pool realist switch gane like',
#  'think game would good choos countri player lso f# g cheater like foreign countri like ndia need ban make game realli unenjoy play cheat #hole quit game get away give win think develop need crack lousi tallent player would keep track report number give develop thought would help develop problem take money care integr game honest player eliev better pool game eventu everyon go one know ii problem keep',
#  'game rig complet pin wheel never pay big extra guidelin remov certain level hot defi basic law physic matter',
#  'lassic ant beat good quick game 8 ball ven rooki noobi enjoy realli learn curv nli downsid requir connect play',
#  'realli enjoy play game sometim feel like addict spin howev kinda like prank push earn coin legitim hank develop',
#  'hen play game n suddenli hv rcv miss call game loss connect kp connect hat main problem therwis game ood hank',
#  'ts good game ut ue realli hard unlock nd pin get coin less 500 would rate higher chang',
#  'reat game contain mani bug struck play suggest mani unnecessari display middl game today play game even game declar oppon winner eat ram intern memori cach make smart phone lag',
#  'un game rig dont mind spend money game constantli lose take money rig spent money never receiv coin etc 2 occas refund either',
#  'ts awesom game eri realist addict nli thing suck connect problem player name ohammad ohammad moham md rig match think 80 match rig',
#  'game becam passion want give five star challeng keep charm game play ever far andi rush',
#  'start love app 1st put cash took week realiz half game program real peopl ake player drive sale swindl bad otherwis real great product put cash month first thing happen bet make 10 fix loss lost million unfair game peopl still play 4 5 game fix humb',
#  'would give 5 star took away lag freez everi 5 second phone game bring reason give 5 tar time time origin pool time fact freez everi 5 econd go well fact time timer keep go even though stop everyth els pretti good',
#  'game continu take coin reason ost peopl mod pocket ball weight way mess ix bug fix remov modder game would fun',
#  'good game club free spin stuff like howev let log fb googl friend fb googl stubborn im go differ pool game',
#  'un game nli bad thing hard play game cost half million take long get much coin',
#  'irst need work rotat screen game cannot provid doubl side full screen support ajor drawback',
#  'ome pay win aspect also work way buy good que game dollar earn 1 free day would like supris box bit fairer order level pay win player overal great addict game',
#  'ardest infin addict game henev bore want spend time play game tension free nce start abl leav game wesom game till play',
#  'simpli idea oppon player pick logic nd mani compuls make purchas someth',
#  'must put ondura cue seem like took time read review abl challeng amount money coin u happen',
#  'thing would like see done lower level player get stuck higher level nd game wheel hit big number small number ever time',
#  'reat game drop star new updat club glitchi club leaderboard constantli display inaccur amount exampl said 67mil 330mil went 150 mil drop sinc ive 1 05bill say 450 someth million make sens that near even half ive whilst club profit margin ive either leas fix',
#  'fter year still need work ot best game ok guess',
#  'good game 7 day becom addict nli complain get 250 500 daili spin reward show daili spin',
#  'f got call play automat enter home irrit olv issu',
#  'happi break ball time get break 4 5 game continu',
#  'eep de sync mid game player constantli disconnect nd connect therwis would given least 4 star',
#  'ame play total bogu ust win game stall say slow connect hen say excel connect otal',
#  'ould much better could easili make pic facebook profil littl thing like bring',
#  'thing nice admin plzzz help upload facebook photo im mayb 6 year old player 8 ball wrong u help admin plzzz',
#  'ould better 8 ball break win rather spot back tabl 9 break win eight',
#  'alway make winner oppon network issu oesn matter network issu belong oppon ate',
#  'ove game updat ow open even allow practic offlin retti disappoint spend much time build stat gain level etc guess option uninstal ot cool',
#  'pretti good game notic need pay way much attent power pool stick along shot timer much',
#  'pin nd purchas r rig develop scratch n win never give reward nd poor gameplay high level player keep get benifit nt gud',
#  'ver sinc updat lose game time run much faster alf time show still time clock turn end abruptli say ran time r middl aim cue disappear time run hat frustrat dite play 5 game straight w break worst pool game',
#  'un game cue upgrad littl thing take beyond pool game lso spam ad like free game',
#  'sir new updat awesom u solv issu issu play well club last time kickout mani member u plzz solv issu plzz sir',
#  'reat addict game ne thing guy improv thingi make differ gold also spin thing alway get 100 75',
#  'ove game ith love graphic control f look past flashi sale pitch haunt free play game amaz wish paid version without push messag sale stuff',
#  'love game get troubl everyday thing wrong straight shot make pocket',
#  'fu king stupid glitch much advic instal fuc ing stupid game wast time',
#  'ot play game anymor default lobbi max chip mention even confirm window make three time accident select game risk chip absolut want f someon select lobbi play within default back highest everi singl time ust anoth way potenti lose chip buy reinto mh',
#  'spin wheel rig ther dont get play peopl rank dont get rank efund coin hey cant dissapear eri addict game entertain owev coin finish request gift peopl onlin appear someth hourli bonu someth player keep play without actual purchas coin play',
#  'est game want say 2 point 1 want say creator game add voic convers option game make excit 2 dd option watch other game tournament play ome time get bore ou win quaterfin semifin inal match oppon 1st match bore fell everyon suggest add featur see other game tournament match',
#  'love new club cool club actual prize like sticker shirt cue hat honesti anyth would cool advertis spread word game game prize like cue big coin mini game chat custom tabl u challeng someon would dope diffent need new profil pic win purchas keep see lame one anyth make custom player anyth player win would major upgrad sure must game classic mine year',
#  'est pool game awar et redit card readi nd pay oney best money make machin creator owner hey need oupl privat et time ou accid push 5 million game want play high stake nd hink friend that plan',
#  'better pool game oogl lay slightli buggi hen oppon connect stabl suddenli say run time even though made shot also seem support push timer need b obviou run',
#  'ame alright bit sketchi either oppon bad connect pool cue power bar need look annoy tri get right amount power suddenli start move angl finger move bar',
#  'realli like game tri ti purchas halloween pack twice amount got deduct bank account transact pool show declin ould u pleas let knw whether get pack money back',
#  'wesom like look see ickatnyt play olt lad ad club game need ne thing though player get hope win big daili spin rig get low prize',
#  'free spin joke 4 slot 250 lower alway land 4 16 dd say control u spend money eem like play ton bot here merican',
#  'ealli hat think game awesom play tabl pool time game real life pool eopl complain control develop fault individu fault f know manipul easi 8 pool peac men',
#  'actual addict game seem wierd critic time game go win match game shut time get reboot lost nli time ever critic moment never play romis game total rig hat perfectli clear spin wheel alway land low #s hat chanc otherwis ig',
#  'orst server ran rom first time tri game acout messag connect slow tri best network ran ecent even connect game time leas consid better server caus mani ranian love game',
#  'unni game never see cue batteri insid ou earn upgrad pay coin stupid ut recharg cue u use stupid thing back star keep ask rate game stil noth improv call pocket game pot ball wrong pocket ball hand oppon lose turn',
#  'previou profil howev updat lost 1 5 million coin rank ow sad frustrat start f 8 ball fix give five star',
#  'ake money differ rate 11700 coin went 2500 game lost round come money gone lso offer get coin dont get ix glitch idiot want coin back',
#  'reat game se play mini clip year ago ook star cant block peopl play poorli e purpos scratch break scratch caus dont shot ont play like bitch',
#  ...]

# %%
#Finding the most commonly used words

# %%
words = [] #array to store most commonly used words
Sentiment_Polarity=[] #array to 
for i in range(0,len(corpus)):
    words = words + (re.findall(r'\w+', corpus[i]))# words contain all the words in the dataset
    Sentiment_Polarity.append
words
# Out:
# ['like',
#  'eat',
#  'delici',
#  'food',
#  'hat',
#  'cook',
#  'food',
#  'case',
#  '10',
#  'est',
#  'ood',
#  'help',
#  'lot',
#  'also',
#  'est',
#  'efor',
#  'helf',
#  'ife',
#  'help',
#  'eat',
#  'healthi',
#  'exercis',
#  'regular',
#  'basi',
#  'ork',
#  'great',
#  'especi',
#  'go',
#  'groceri',
#  'store',
#  'est',
#  'idea',
#  'us',
#  'est',
#  'way',
#  'maze',
#  'ook',
#  'forward',
#  'app',
#  'help',
#  'site',
#  'help',
#  'food',
#  'get',
#  'good',
#  'seful',
#  'inform',
#  'amount',
#  'spell',
#  'error',
#  'question',
#  'valid',
#  'inform',
#  'share',
#  'nce',
#  'fix',
#  '5',
#  'star',
#  'given',
#  'hank',
#  'reat',
#  'app',
#  'dd',
#  'arthriti',
#  'eye',
#  'immun',
#  'kidney',
#  'liver',
#  'detox',
#  'food',
#  'pleas',
#  'reatest',
#  'ever',
#  'omplet',
#  'awesom',
#  'maintain',
#  'health',
#  'must',
#  'ppl',
#  'ove',
#  'ood',
#  'health',
#  'ood',
#  'health',
#  'first',
#  'prioriti',
#  'ealth',
#  'import',
#  'world',
#  'either',
#  'life',
#  'think',
#  'rs',
#  'sunita',
#  'bhati',
#  'thank',
#  'develop',
#  'make',
#  'kind',
#  'app',
#  'realli',
#  'good',
#  'healthi',
#  'food',
#  'bodi',
#  'eri',
#  'seful',
#  'diabet',
#  'age',
#  '30',
#  'need',
#  'control',
#  'sugar',
#  'thank',
#  'ne',
#  'greatest',
#  'app',
#  'good',
#  'nice',
#  'ealthi',
#  'ealli',
#  'help',
#  'od',
#  'health',
#  '5',
#  'n',
#  'excel',
#  'use',
#  'found',
#  'lot',
#  'wealth',
#  'form',
#  'health',
#  'ecaus',
#  'found',
#  'import',
#  'ealthi',
#  'ate',
#  'eri',
#  'good',
#  'impli',
#  'good',
#  'n',
#  'test',
#  'ood',
#  'hank',
#  'advic',
#  'ownload',
#  'dobe',
#  'reader',
#  'still',
#  'get',
#  'recip',
#  'book',
#  'recip',
#  'book',
#  'nabl',
#  'recip',
#  'book',
#  'bsolut',
#  'abul',
#  'henomen',
#  'reat',
#  'ove',
#  'food',
#  'xcellent',
#  'realli',
#  'work',
#  'est',
#  'eri',
#  'inform',
#  'easi',
#  'understand',
#  'ad',
#  'middl',
#  'page',
#  'interupt',
#  'read',
#  'pdate',
#  'ad',
#  'comment',
#  'object',
#  'ad',
#  'liter',
#  'posit',
#  'ad',
#  'mack',
#  'dab',
#  'new',
#  'spartphon',
#  'app',
#  'idnt',
#  'know',
#  'lick',
#  'eveyth',
#  'saw',
#  'ut',
#  'ull',
#  'eview',
#  'ot',
#  'descript',
#  'good',
#  'reat',
#  'app',
#  'ove',
#  'ood',
#  'ove',
#  'eri',
#  'help',
#  'ood',
#  'healthi',
#  'food',
#  'ast',
#  'time',
#  'need',
#  'internet',
#  'time',
#  'n',
#  'ask',
#  'call',
#  'inform',
#  'est',
#  'thing',
#  'lost',
#  'ten',
#  'lb',
#  'two',
#  'month',
#  'help',
#  'tip',
#  'en',
#  'best',
#  'food',
#  'promot',
#  'good',
#  'health',
#  'ood',
#  'health',
#  'essenti',
#  'long',
#  'healthi',
#  'lifestyl',
#  'make',
#  'habit',
#  'eat',
#  'food',
#  'promot',
#  'good',
#  'health',
#  'fruit',
#  'veggi',
#  'everi',
#  'day',
#  'ealthi',
#  'ood',
#  'ealli',
#  'good',
#  'inform',
#  'eat',
#  'healthi',
#  'mom',
#  'dad',
#  'import',
#  'thing',
#  'good',
#  'share',
#  'big',
#  'thank',
#  'ds',
#  'got',
#  'bst',
#  'gd',
#  'health',
#  'ove',
#  'est',
#  'everyon',
#  'need',
#  'ove',
#  'lost',
#  '6',
#  'ound',
#  'far',
#  '215',
#  '209',
#  'like',
#  'hank',
#  'help',
#  'app',
#  'good',
#  'food',
#  'realli',
#  'good',
#  'eat',
#  'hank',
#  'hank',
#  'u',
#  'much',
#  'ove',
#  'realli',
#  'good',
#  'help',
#  'love',
#  'eri',
#  'use',
#  'reat',
#  'ove',
#  'eri',
#  'inform',
#  'uv',
#  'great',
#  'onder',
#  'oesn',
#  'work',
#  'ero',
#  'eight',
#  'loss',
#  'ot',
#  'bad',
#  '10',
#  'best',
#  'food',
#  '4u',
#  'xcellent',
#  'chose',
#  'food',
#  'need',
#  'altu',
#  'plz',
#  'wast',
#  'ur',
#  'time',
#  'est',
#  'food',
#  'hank',
#  'recip',
#  'book',
#  'ove',
#  'ood',
#  'like',
#  'uperb',
#  'ood',
#  'good',
#  'ealthi',
#  'uick',
#  'ead',
#  'reat',
#  'idea',
#  'oo',
#  'good',
#  'ool',
#  'ood',
#  'ood',
#  'est',
#  'est',
#  'reat',
#  'reat',
#  'ood',
#  'list',
#  'easi',
#  'predibet',
#  'scare',
#  'r',
#  'said',
#  'potato',
#  'rice',
#  'bread',
#  'e',
#  'never',
#  'told',
#  'could',
#  'eat',
#  'suppli',
#  'paperwork',
#  'state',
#  'thing',
#  'could',
#  'happen',
#  'tell',
#  'get',
#  'work',
#  'hank',
#  'calm',
#  'reat',
#  'wife',
#  'wife',
#  'enjoy',
#  'much',
#  'kinda',
#  'person',
#  'like',
#  'follow',
#  'health',
#  'diet',
#  'spend',
#  'much',
#  'time',
#  'front',
#  'find',
#  'appropri',
#  'diet',
#  'food',
#  'ow',
#  'found',
#  'magnific',
#  'app',
#  'hank',
#  'humb',
#  'reat',
#  'eri',
#  'interest',
#  'use',
#  'applic',
#  'like',
#  'rap',
#  'oesn',
#  'work',
#  '5',
#  'starr',
#  'ownload',
#  'like',
#  'help',
#  'nice',
#  'super',
#  'get',
#  'ice',
#  'ice',
#  'collect',
#  'ow',
#  'nterest',
#  'interest',
#  'info',
#  'think',
#  'worth',
#  'storag',
#  'space',
#  'phone',
#  'rather',
#  'research',
#  'comput',
#  'print',
#  'list',
#  'eat',
#  'idea',
#  'make',
#  'life',
#  'easier',
#  'provid',
#  'entertain',
#  'expect',
#  'app',
#  'uv',
#  'impl',
#  'easi',
#  'understand',
#  'well',
#  'thought',
#  'follow',
#  'step',
#  'step',
#  'problem',
#  'see',
#  'result',
#  'also',
#  'luv',
#  'app',
#  'give',
#  'food',
#  'choic',
#  'ut',
#  'look',
#  'like',
#  'foundat',
#  'eep',
#  'good',
#  'work',
#  'ot',
#  'good',
#  'ts',
#  'good',
#  'u',
#  'net',
#  'connect',
#  'u',
#  'play',
#  'app',
#  'much',
#  'good',
#  'wesom',
#  'resourc',
#  'begin',
#  'new',
#  'journey',
#  'see',
#  'great',
#  'result',
#  'ore',
#  'thought',
#  'actual',
#  'text',
#  'oo',
#  'poor',
#  'old',
#  'text',
#  'ove',
#  'app',
#  'give',
#  'way',
#  'good',
#  'idea',
#  'buy',
#  'store',
#  'eat',
#  'daili',
#  'basi',
#  'reat',
#  'ts',
#  'realli',
#  'best',
#  'uniqu',
#  'provid',
#  'detail',
#  'inform',
#  'food',
#  'nutriti',
#  'stay',
#  'healthi',
#  'hat',
#  'develop',
#  'give',
#  'free',
#  'oth',
#  'special',
#  'ould',
#  'find',
#  'anyth',
#  'use',
#  'ts',
#  'ok',
#  'love',
#  'ok',
#  'like',
#  'eat',
#  'delici',
#  'food',
#  'hat',
#  'cook',
#  'food',
#  'case',
#  '10',
#  'est',
#  'ood',
#  'help',
#  'lot',
#  'also',
#  'est',
#  'efor',
#  'helf',
#  'ife',
#  'help',
#  'eat',
#  'healthi',
#  'exercis',
#  'regular',
#  'basi',
#  'ork',
#  'great',
#  'especi',
#  'go',
#  'groceri',
#  'store',
#  'est',
#  'idea',
#  'us',
#  'est',
#  'way',
#  'maze',
#  'ook',
#  'forward',
#  'app',
#  'help',
#  'site',
#  'help',
#  'food',
#  'get',
#  'good',
#  'seful',
#  'inform',
#  'amount',
#  'spell',
#  'error',
#  'question',
#  'valid',
#  'inform',
#  'share',
#  'nce',
#  'fix',
#  '5',
#  'star',
#  'given',
#  'hank',
#  'reat',
#  'app',
#  'dd',
#  'arthriti',
#  'eye',
#  'immun',
#  'kidney',
#  'liver',
#  'detox',
#  'food',
#  'pleas',
#  'reatest',
#  'ever',
#  'omplet',
#  'awesom',
#  'maintain',
#  'health',
#  'must',
#  'ppl',
#  'ove',
#  'ood',
#  'health',
#  'ood',
#  'health',
#  'first',
#  'prioriti',
#  'ealth',
#  'import',
#  'world',
#  'either',
#  'life',
#  'think',
#  'rs',
#  'sunita',
#  'bhati',
#  'thank',
#  'develop',
#  'make',
#  'kind',
#  'app',
#  'realli',
#  'good',
#  'healthi',
#  'food',
#  'bodi',
#  'eri',
#  'seful',
#  'diabet',
#  'age',
#  '30',
#  'need',
#  'control',
#  'sugar',
#  'thank',
#  'ne',
#  'greatest',
#  'app',
#  'good',
#  'nice',
#  'ealthi',
#  'ealli',
#  'help',
#  'od',
#  'health',
#  '5',
#  'n',
#  'excel',
#  'use',
#  'found',
#  'lot',
#  'wealth',
#  'form',
#  'health',
#  'ecaus',
#  'found',
#  'import',
#  'ealthi',
#  'ate',
#  'eri',
#  'good',
#  'impli',
#  'good',
#  'n',
#  'test',
#  'ood',
#  'hank',
#  'advic',
#  'ownload',
#  'dobe',
#  'reader',
#  'still',
#  'get',
#  'recip',
#  'book',
#  'recip',
#  'book',
#  'nabl',
#  'recip',
#  'book',
#  'bsolut',
#  'abul',
#  'henomen',
#  'reat',
#  'ove',
#  'food',
#  'xcellent',
#  'realli',
#  'work',
#  'est',
#  'eri',
#  'inform',
#  'easi',
#  'understand',
#  'ad',
#  'middl',
#  'page',
#  'interupt',
#  'read',
#  'pdate',
#  'ad',
#  'comment',
#  'object',
#  'ad',
#  'liter',
#  'posit',
#  'ad',
#  'mack',
#  'dab',
#  'new',
#  'spartphon',
#  'app',
#  'idnt',
#  'know',
#  'lick',
#  'eveyth',
#  'saw',
#  'ut',
#  'ull',
#  'eview',
#  'ot',
#  'descript',
#  'good',
#  'reat',
#  'app',
#  'ove',
#  'ood',
#  'ove',
#  'eri',
#  'help',
#  'ood',
#  'healthi',
#  'food',
#  'ast',
#  'time',
#  'need',
#  'internet',
#  'time',
#  'n',
#  'ask',
#  'call',
#  'inform',
#  'est',
#  'thing',
#  'lost',
#  'ten',
#  'lb',
#  'two',
#  'month',
#  'help',
#  'tip',
#  'en',
#  'best',
#  'food',
#  'promot',
#  'good',
#  'health',
#  'ood',
#  'health',
#  'essenti',
#  'long',
#  'healthi',
#  'lifestyl',
#  'make',
#  'habit',
#  'eat',
#  'food',
#  'promot',
#  'good',
#  'health',
#  'fruit',
#  'veggi',
#  'everi',
#  'day',
#  'ealthi',
#  'ood',
#  'ealli',
#  'good',
#  'inform',
#  'eat',
#  'healthi',
#  'mom',
#  'dad',
#  'import',
#  'thing',
#  'good',
#  'share',
#  'big',
#  'thank',
#  'ds',
#  'got',
#  'bst',
#  'gd',
#  'health',
#  'ove',
#  'est',
#  'everyon',
#  'need',
#  'ove',
#  'lost',
#  '6',
#  'ound',
#  'far',
#  '215',
#  '209',
#  'like',
#  'hank',
#  'help',
#  'app',
#  'good',
#  'food',
#  'realli',
#  'good',
#  'eat',
#  'hank',
#  'hank',
#  'u',
#  'much',
#  'ove',
#  'realli',
#  'good',
#  'help',
#  'love',
#  'eri',
#  'use',
#  'reat',
#  'ove',
#  'eri',
#  'inform',
#  'uv',
#  'great',
#  'onder',
#  'oesn',
#  'work',
#  'ero',
#  'eight',
#  'loss',
#  'ot',
#  'bad',
#  '10',
#  'best',
#  'food',
#  '4u',
#  'xcellent',
#  'chose',
#  'food',
#  'need',
#  'altu',
#  'plz',
#  'wast',
#  'ur',
#  'time',
#  'est',
#  'food',
#  'hank',
#  'recip',
#  'book',
#  'ove',
#  'ood',
#  'like',
#  'uperb',
#  'ood',
#  'good',
#  'ealthi',
#  'uick',
#  'ead',
#  'reat',
#  'idea',
#  'oo',
#  'good',
#  'ool',
#  'ood',
#  'ood',
#  'est',
#  'est',
#  'reat',
#  'reat',
#  'ood',
#  'list',
#  'easi',
#  'predibet',
#  'scare',
#  'r',
#  'said',
#  'potato',
#  'rice',
#  'bread',
#  'e',
#  'never',
#  'told',
#  'could',
#  'eat',
#  'suppli',
#  'paperwork',
#  'state',
#  'thing',
#  'could',
#  'happen',
#  'tell',
#  'get',
#  'work',
#  'hank',
#  'calm',
#  'reat',
#  'wife',
#  'wife',
#  'enjoy',
#  'much',
#  'kinda',
#  'person',
#  'like',
#  'follow',
#  'health',
#  'diet',
#  'spend',
#  'much',
#  'time',
#  'front',
#  'find',
#  'appropri',
#  'diet',
#  'food',
#  'ow',
#  'found',
#  'magnific',
#  'app',
#  'hank',
#  'humb',
#  'reat',
#  'eri',
#  'interest',
#  'use',
#  'applic',
#  'like',
#  'rap',
#  'oesn',
#  'work',
#  '5',
#  'starr',
#  'ownload',
#  'like',
#  'help',
#  'nice',
#  'super',
#  'get',
#  'ice',
#  'ice',
#  'collect',
#  'ow',
#  'nterest',
#  'interest',
#  'info',
#  'think',
#  'worth',
#  'storag',
#  'space',
#  'phone',
#  'rather',
#  'research',
#  'comput',
#  'print',
#  'list',
#  'eat',
#  'idea',
#  'make',
#  'life',
#  'easier',
#  'provid',
#  'entertain',
#  'expect',
#  'app',
#  'uv',
#  'impl',
#  'easi',
#  'understand',
#  'well',
#  'thought',
#  'follow',
#  'step',
#  'step',
#  'problem',
#  ...]

# %%
#from PIL import Image
#from wordcloud import WordCloud

# %%
#def wc(data,bgcolor,title):
#plt.figure(figsize = (80,80))
#wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 95)
#wc.generate(' '.join(data))
#plt.imshow(wc)
#plt.axis('off')

# %%
#wc(words,'white','love')

# %%
from collections import Counter
#A counter is a container that stores elements as dictionary keys, and their counts are stored as dictionary values.

# %%
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)
most_commmom_wordList = []
most_commmom_CountList = []
for x, y in most_common_words:
    most_commmom_wordList.append(x)
    most_commmom_CountList.append(y)

# %%
plt.figure(figsize=(20,18))
plot = sns.barplot(np.arange(30), most_commmom_CountList[0:30]) #width=0.35)
plt.ylabel('Word Count',fontsize=20)
plt.xticks(np.arange(30), most_commmom_wordList[0:30], fontsize=20, rotation=45)
plt.title('Most Common Word used in the Review.', fontsize=20)
plt.show()

# %%
k = most_commmom_wordList[0:30]
Sentiment_Polarity=[]
EmotionallyPositive=[]
RationallyPositive=[]
Neutral=[]
RationallyNegative=[]
EmotionallyNegative=[]
for i in k:
    Sentiment=[]
    for z in corpus:
        #if i in z:
            #Sentiment.append(Data['Sentiment_Polarity'][corpus.index(z)])
    #Sentiment_Polarity.append(Sentiment)
        if i in z and Data['Sentiment'][corpus.index(z)]=='Emotionally Positive':
            EmotionallyPositive.append(i)
        if i in z and Data['Sentiment'][corpus.index(z)]=='Rationally Positive':
            RationallyPositive.append(i)
        if i in z and Data['Sentiment'][corpus.index(z)]=='Neutral':
            Neutral.append(i)
        if i in z and Data['Sentiment'][corpus.index(z)]=='Rationally Negative':
            RationallyNegative.append(i)
        if i in z and Data['Sentiment'][corpus.index(z)]=='Emotionally Negative':
            EmotionallyNegative.append(i)

# %%
f,ax = plt.subplots(5,1,figsize=(20,40))
c1 = sns.countplot(EmotionallyPositive, ax=ax[0])
c2 = sns.countplot(RationallyPositive, ax=ax[1])
c3 = sns.countplot(Neutral,ax=ax[2])
c4 = sns.countplot(RationallyNegative,ax=ax[3])
c5 = sns.countplot(EmotionallyNegative,ax=ax[4])
ax[0].set_title("Number of times Most Common Words \nused in case of EMOTIONALLY POSITIVE Review",fontsize=20)
ax[1].set_title("Number of times Most Common Words \nused in case of RATIONALLY POSITIVE Review",fontsize=20)
ax[2].set_title("Number of times Most Common Words \nused in case of NEUTRAL Review",fontsize=20)
ax[3].set_title("Number of times Most Common Words \nused in case of RATIONALLY NEGATIVE Review",fontsize=20)
ax[4].set_title("Number of times Most Common Words \nused in case of EMOTIONALLY NEGATIVE Review",fontsize=20)
plt.show()
